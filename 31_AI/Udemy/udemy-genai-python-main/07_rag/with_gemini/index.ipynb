# %% [markdown]
# ### RAG with Langchain - Using Qdrant DB

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#import all dependencies
from dotenv import load_dotenv

from pathlib import Path
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_qdrant import QdrantVectorStore

# %%
load_dotenv()

pdf_path = Path("/Users/priyaupadhyay/Desktop/sudhanshu/Code/InterviewPrep-2025/31_AI/Udemy/udemy-genai-python-main/07_rag") / "nodejs.pdf"

print(pdf_path)
# Out:
# /Users/priyaupadhyay/Desktop/sudhanshu/Code/InterviewPrep-2025/31_AI/Udemy/udemy-genai-python-main/07_rag/nodejs.pdf

# %%
from google import genai
import os

client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))
for model in client.models.list():
    if "embed" in model.name:
        print(model.name)
# Out:
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
